# %%
from ProjectPaths import ProjectPaths
import os

# %%
image_files_2016_2017 = os.listdir(os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75"))
image_files_2016_2017.sort()
image_files_2016_2017[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017.tiff']

# %%
len(image_files_2016_2017)
# Out:
# 1050204

# %%
image_files_2016_rgb = [filename for filename in image_files_2016_2017 if filename.endswith("rgb_2016.tiff")]
image_files_2016_rgb[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2016.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2016.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2016.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2016.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2016.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2016.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2016.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2016.tiff',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781_rgb_2016.tiff']

# %%
len(image_files_2016_rgb)
# Out:
# 87517

# %%
image_files_2017_rgb = [filename for filename in image_files_2016_2017 if filename.endswith("rgb_2017.tiff")]
image_files_2017_rgb[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2017.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2017.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2017.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2017.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2017.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2017.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2017.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2017.tiff',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781_rgb_2017.tiff']

# %%
len(image_files_2017_rgb)
# Out:
# 87517

# %%
image_files_2018 = os.listdir(os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2018"))
image_files_2018.sort()
image_files_2018[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2018.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2018_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2018_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2018.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2018_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2018_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2018.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2018_mask.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2018_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2018.tiff']

# %%
image_files_2018_rgb = [filename for filename in image_files_2018 if filename.endswith("rgb_2018.tiff")]
image_files_2018_rgb[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2018.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2018.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2018.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2018.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2018.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2018.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2018.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2018.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2018.tiff',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781_rgb_2018.tiff']

# %%
len(image_files_2018_rgb)
# Out:
# 87517

# %%
def rchop(string, substring):
    return string[:-len(substring)] if string.endswith(substring) else string

# %%
def rchop_list(file_list, substring):
    return [rchop(filename, substring) for filename in file_list]

# %%
uuid_2016 = rchop_list(image_files_2016_rgb, "_rgb_2016.tiff")
uuid_2016[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781']

# %%
uuid_2017 = rchop_list(image_files_2017_rgb, "_rgb_2017.tiff") 
uuid_2017[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781']

# %%
uuid_2018 = rchop_list(image_files_2018_rgb, "_rgb_2018.tiff") 
uuid_2018[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781']

# %%
diff_2017_2016 = set(uuid_2017) - set(uuid_2016)
diff_2017_2016
# Out:
# set()

# %%
diff_2016_2017 = set(uuid_2016) - set(uuid_2017)
diff_2016_2017
# Out:
# set()

# %%
diff_2016_2018 = set(uuid_2018) ^ set(uuid_2016)
diff_2016_2018
# Out:
# set()

# %%
diff_2017_2018 = set(uuid_2018) ^ set(uuid_2017)
diff_2017_2018
# Out:
# set()

# %%
image_files_2013 = os.listdir(os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2013"))
image_files_2013.sort()
image_files_2013[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2013.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2013_mask.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2013_masked.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2013.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2013_mask.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2013_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2013.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2013_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2013_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2013.tiff']

# %%
image_files_2014 = os.listdir(os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2014"))
image_files_2014.sort()
image_files_2014[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2014.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2014_mask.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2014_masked.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2014.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2014_mask.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2014_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2014.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2014_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2014_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2014.tiff']

# %%
image_files_2015 = os.listdir(os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2015"))
image_files_2015.sort()
image_files_2015[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2015.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2015_mask.tiff',
#  '0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2015_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2015.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2015_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2015_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2015.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2015_mask.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2015_masked.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2015.tiff']

# %%
image_files_2013_rgb = [filename for filename in image_files_2013 if filename.endswith("rgb_2013.tiff")]
image_files_2013_rgb[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2013.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2013.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2013.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2013.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2013.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2013.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2013.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2013.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2013.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2013.tiff']

# %%
len(image_files_2013_rgb)
# Out:
# 87797

# %%
image_files_2014_rgb = [filename for filename in image_files_2014 if filename.endswith("rgb_2014.tiff")]
image_files_2014_rgb[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2014.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2014.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2014.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2014.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2014.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2014.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2014.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2014.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2014.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2014.tiff']

# %%
len(image_files_2014_rgb)
# Out:
# 87797

# %%
image_files_2015_rgb = [filename for filename in image_files_2015 if filename.endswith("rgb_2015.tiff")]
image_files_2015_rgb[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2015.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2015.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2015.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2015.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2015.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2015.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2015.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2015.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2015.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2015.tiff']

# %%
len(image_files_2015_rgb)
# Out:
# 87797

# %%
uuid_2013 = rchop_list(image_files_2013_rgb, "_rgb_2013.tiff")
uuid_2013[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb']

# %%
uuid_2014 = rchop_list(image_files_2014_rgb, "_rgb_2014.tiff")
uuid_2014[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb']

# %%
uuid_2015 = rchop_list(image_files_2015_rgb, "_rgb_2015.tiff")
uuid_2015[:10]
# Out:
# ['0000085b-6f4a-475a-b800-9ed7619e8a67',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb']

# %%
len(uuid_2013), len(uuid_2014), len(uuid_2015)
# Out:
# (87797, 87797, 87797)

# %%
diff_2013_2016 = set(uuid_2013) ^ set(uuid_2016)
len(diff_2013_2016)
# Out:
# 280

# %%
diff_2013_2016
# Out:
# {'0000085b-6f4a-475a-b800-9ed7619e8a67',
#  '00bcb86c-c04b-4deb-a98b-b29c593f36c5',
#  '0391ea6d-b2d1-4c92-a215-80293259be2a',
#  '047d2c9c-ea9d-4201-af0f-d2b3763c3cfd',
#  '04930d38-900d-462f-8774-30a73f2727ed',
#  '05e2c0a7-7150-4b09-a7da-f063b69abc04',
#  '06acb191-3989-42f5-bea3-954843bc1870',
#  '09e8d47d-38ed-4d2c-bf0d-ae694c0d9e1e',
#  '0ac5288a-9d71-443c-9c0a-9647df36f648',
#  '0b4a5392-e0bd-460e-b5eb-2f63a79edf81',
#  '0ba466b3-afa1-44b6-b1ae-d8f08c312468',
#  '0dbe3653-1434-4468-9c42-5bbb7a8482b7',
#  '0fccedb5-5bb2-43df-aedc-7b5428ee96c9',
#  '12cf7e0b-62cd-4d82-b377-a097087e03ec',
#  '13cf66ac-3d82-4da7-bef8-9b2b26c2dc57',
#  '13d720b8-08cd-4a54-ab3d-2c864daca05d',
#  '14d34989-77ef-4824-b264-46fa4a9f1531',
#  '15243f33-40da-49bd-9ef0-08eb4db2eacb',
#  '15a47bf8-1105-466c-a77a-0e723aacf1d2',
#  '15d9561e-b1ba-47e6-8e38-4e0c8672e1d2',
#  '15f075b3-1598-4d18-a6b4-182f7af8983d',
#  '1700fe4d-52e8-4b25-ab87-5f9dd889f8c6',
#  '1709e4a3-80b6-47c4-999b-9c0c888369dd',
# ...

# %%
diff_2014_2016 = set(uuid_2014) ^ set(uuid_2016)
len(diff_2014_2016)
# Out:
# 280

# %%
diff_2014_2016
# Out:
# {'0000085b-6f4a-475a-b800-9ed7619e8a67',
#  '00bcb86c-c04b-4deb-a98b-b29c593f36c5',
#  '0391ea6d-b2d1-4c92-a215-80293259be2a',
#  '047d2c9c-ea9d-4201-af0f-d2b3763c3cfd',
#  '04930d38-900d-462f-8774-30a73f2727ed',
#  '05e2c0a7-7150-4b09-a7da-f063b69abc04',
#  '06acb191-3989-42f5-bea3-954843bc1870',
#  '09e8d47d-38ed-4d2c-bf0d-ae694c0d9e1e',
#  '0ac5288a-9d71-443c-9c0a-9647df36f648',
#  '0b4a5392-e0bd-460e-b5eb-2f63a79edf81',
#  '0ba466b3-afa1-44b6-b1ae-d8f08c312468',
#  '0dbe3653-1434-4468-9c42-5bbb7a8482b7',
#  '0fccedb5-5bb2-43df-aedc-7b5428ee96c9',
#  '12cf7e0b-62cd-4d82-b377-a097087e03ec',
#  '13cf66ac-3d82-4da7-bef8-9b2b26c2dc57',
#  '13d720b8-08cd-4a54-ab3d-2c864daca05d',
#  '14d34989-77ef-4824-b264-46fa4a9f1531',
#  '15243f33-40da-49bd-9ef0-08eb4db2eacb',
#  '15a47bf8-1105-466c-a77a-0e723aacf1d2',
#  '15d9561e-b1ba-47e6-8e38-4e0c8672e1d2',
#  '15f075b3-1598-4d18-a6b4-182f7af8983d',
#  '1700fe4d-52e8-4b25-ab87-5f9dd889f8c6',
#  '1709e4a3-80b6-47c4-999b-9c0c888369dd',
# ...

# %%
diff_2015_2016 = set(uuid_2015) ^ set(uuid_2016)
len(diff_2015_2016)
# Out:
# 280

# %%
diff_2015_2016
# Out:
# {'0000085b-6f4a-475a-b800-9ed7619e8a67',
#  '00bcb86c-c04b-4deb-a98b-b29c593f36c5',
#  '0391ea6d-b2d1-4c92-a215-80293259be2a',
#  '047d2c9c-ea9d-4201-af0f-d2b3763c3cfd',
#  '04930d38-900d-462f-8774-30a73f2727ed',
#  '05e2c0a7-7150-4b09-a7da-f063b69abc04',
#  '06acb191-3989-42f5-bea3-954843bc1870',
#  '09e8d47d-38ed-4d2c-bf0d-ae694c0d9e1e',
#  '0ac5288a-9d71-443c-9c0a-9647df36f648',
#  '0b4a5392-e0bd-460e-b5eb-2f63a79edf81',
#  '0ba466b3-afa1-44b6-b1ae-d8f08c312468',
#  '0dbe3653-1434-4468-9c42-5bbb7a8482b7',
#  '0fccedb5-5bb2-43df-aedc-7b5428ee96c9',
#  '12cf7e0b-62cd-4d82-b377-a097087e03ec',
#  '13cf66ac-3d82-4da7-bef8-9b2b26c2dc57',
#  '13d720b8-08cd-4a54-ab3d-2c864daca05d',
#  '14d34989-77ef-4824-b264-46fa4a9f1531',
#  '15243f33-40da-49bd-9ef0-08eb4db2eacb',
#  '15a47bf8-1105-466c-a77a-0e723aacf1d2',
#  '15d9561e-b1ba-47e6-8e38-4e0c8672e1d2',
#  '15f075b3-1598-4d18-a6b4-182f7af8983d',
#  '1700fe4d-52e8-4b25-ab87-5f9dd889f8c6',
#  '1709e4a3-80b6-47c4-999b-9c0c888369dd',
# ...

# %%
diff_2013_2014 = set(uuid_2013) ^ set(uuid_2014)
len(diff_2013_2014)
# Out:
# 0

# %%
diff_2014_2015 = set(uuid_2014) ^ set(uuid_2015)
len(diff_2014_2015)
# Out:
# 0

# %%
def attach(image_list, substring):
    return ["{}{}".format(filename, substring) for filename in image_list]

def create_path(path, image_list):
    return [os.path.join(path, filename) for filename in image_list]

image_dir_2013 = os.path.join(ProjectPaths.instance().image_dir, "Tiles/Heerlen75x75-2013")
image_dir_2014 = os.path.join(ProjectPaths.instance().image_dir, "Tiles/Heerlen75x75-2014")
image_dir_2015 = os.path.join(ProjectPaths.instance().image_dir, "Tiles/Heerlen75x75-2015")

diff_images_2013 = create_path(image_dir_2013, attach(diff_2013_2016, "_rgb_2013.tiff"))
diff_images_2014 = create_path(image_dir_2014, attach(diff_2014_2016, "_rgb_2014.tiff"))                                           
diff_images_2015 = create_path(image_dir_2015, attach(diff_2015_2016, "_rgb_2015.tiff"))
                               

diff_image_set = zip(diff_images_2013, diff_images_2014, diff_images_2015)

# %%
len(diff_images_2013), len(diff_images_2014), len(diff_images_2015)
# Out:
# (280, 280, 280)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2


image1 = cv2.imread(diff_images_2013[0])[:,:,::-1]
image2 = cv2.imread(diff_images_2014[0])[:,:,::-1]
image3 = cv2.imread(diff_images_2015[0])[:,:,::-1]

_, ax = plt.subplots(1,3)
ax[0].imshow(image1)
ax[1].imshow(image2)
ax[2].imshow(image3)

# %%
_, ax = plt.subplots(10, 3, figsize=(16,16))

for i, image_tuple in enumerate(diff_image_set):
    im_2013, im_2014, im_2015 = image_tuple
   
    ax[i, 0].imshow(cv2.imread(im_2013))
    ax[i, 1].imshow(cv2.imread(im_2014)) 
    ax[i, 2].imshow(cv2.imread(im_2015))
    if i >= 9:
        break

# %%
import gdal

# %%
dataset = gdal.Open(diff_images_2013[0])
dataset
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f267e196810> >

# %%
def getProjectionCoords(dataset, x, y):
        """This method converts the pixel coordinate (x, y) into the coordinate system used
        by the projection of the map.
        The equations used are:
        Xp = transform[0] + x * transform[1] + y * tranform[2]
        
        Yp = transform[3] + x * transform[4] + y * transform[5]
        
        :param int x: the pixel x coordinate
        
        :param int y: the pixel y coordinate
        :return: a tuple with the coordinates in projection space.
        :rtype: tuple (double, double)
        """
        transform = dataset.GetGeoTransform()
        Xp = transform[0] + x * transform[1] + y * transform[2]
        Yp = transform[3] + x * transform[4] + y * transform[5]
        return (Xp, Yp)

# %%
def getBoundingBox(dataset):
    long1, lat1 = getProjectionCoords(dataset, 0, dataset.RasterYSize)
    long2, lat2 = getProjectionCoords(dataset, dataset.RasterXSize, 0)
    return (long1, lat1, long2, lat2)

# %%
bbox = getBoundingBox(dataset)
bbox
# Out:
# (6.01898707106426, 50.93370735879644, 6.0192514696877915, 50.9335373712189)

# %%
import numpy as np

def is_bbox_equal(bbox_left, bbox_right):
    return np.allclose(bbox_left, bbox_right)

# %%
is_bbox_equal(bbox, [0, 0, 0, 0]), is_bbox_equal(bbox, bbox)
# Out:
# (False, True)

# %%
def calc_bboxes(image_paths):
    bboxes = []
    for image_path in image_paths:
        dataset = gdal.Open(image_path)
        bboxes.append((image_path, getBoundingBox(dataset)))
    return bboxes

# %%
image_dir_2016 = os.path.join(ProjectPaths.instance().image_dir, "Tiles/Heerlen75x75")
image_paths_2016 = [os.path.join(image_dir_2016, filename) for filename in image_files_2016_rgb]
bboxes_2016 = calc_bboxes(image_paths_2016)

# %%
len(bboxes_2016)
# Out:
# 87517

# %%
bboxes_2016[:10]
# Out:
# [('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016.tiff',
#   (6.010786618245649,
#    50.83987292848365,
#    6.011050513113969,
#    50.83970296083131)),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00023872-f873-4889-9b80-113677b9e86a_rgb_2016.tiff',
#   (5.971151038580557,
#    50.92637413044208,
#    5.971415571640382,
#    50.92620425193653)),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2016.tiff',
#   (5.993903901373617, 50.89221126746608, 5.994168155928076, 50.8920413375381)),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2016.tiff',
#   (6.010187515656686,
#    50.85470800007116,
#    6.010451496984199,
#    50.85453803357025)),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2016.tiff',
#   (5.938435767303544,
# ...

# %%
from scipy.spatial import distance

def calc_smallest_distance(bbox, image_bboxes):
    distances = [(image_path, distance.euclidean(bbox, image_bbox)) for image_path, image_bbox in image_bboxes]
    distances.sort(key=lambda x: x[1])
    return distances[0]

# %%
# %%timeit -r 1
calc_smallest_distance(bbox, bboxes_2016)
# Out:
# 1.15 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
(19 * 280) / 60
# Out:
# 88.66666666666667

# %%
def calc_smallest_distances(diff_image_paths, compare_image_paths):
    distances = []
    for image_path in diff_image_paths:
        dataset = gdal.Open(image_path)
        bbox = getBoundingBox(dataset)        
        d = calc_smallest_distance(bbox, compare_image_paths)
        distances.append(d)
    return distances

# %%
calc_smallest_distance(bbox, bboxes_2016)
# Out:
# ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/59eb6471-0d68-4b28-9a4a-ec2ecb767cc2_rgb_2016.tiff',
#  5.732020298503412e-14)

# %%
len(diff_images_2013)
# Out:
# 280

# %%
def bboxes_for(diff_image_paths):
    diff_bboxes = []
    for diff_image_path in diff_image_paths:
        dataset = gdal.Open(diff_image_path)
        diff_bboxes.append(getBoundingBox(dataset))  
    return diff_bboxes

# %%
diff_bboxes_2013 = bboxes_for(diff_images_2013)
len(diff_bboxes_2013)
# Out:
# 280

# %%
diff_bboxes_2013[:10]
# Out:
# [(6.01898707106426, 50.93370735879644, 6.0192514696877915, 50.9335373712189),
#  (5.974445198544463, 50.93377337494111, 5.974709761698314, 50.93360348884157),
#  (5.942442429259489, 50.934099866293984, 5.942707112140961, 50.93393005315338),
#  (5.940042050856065, 50.93411135655713, 5.9403067426409155, 50.93394154889067),
#  (5.979781466838728, 50.93391472099465, 5.9800460111399, 50.933744822731605),
#  (5.934707871699086, 50.93413671230663, 5.934972583266897, 50.93396691680597),
#  (5.964577080810508, 50.93382302200634, 5.964841680598153, 50.9336531583998),
#  (5.975512020608215, 50.933767957313215, 5.975776579801002, 50.93359806878228),
#  (5.927773428724871, 50.934169307384344, 5.928038166005751, 50.93399952770094),
#  (5.942975846494648, 50.934097306144096, 5.943240527397504, 50.933927491787)]

# %%
from functools import partial
calc =  partial(calc_smallest_distance, image_bboxes=bboxes_2016)

# %%
from multiprocessing import Pool

p = Pool(5)
smallest_distances_2013 = p.map(calc, diff_bboxes_2013)
smallest_distances_2013
# Out:
# [('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/59eb6471-0d68-4b28-9a4a-ec2ecb767cc2_rgb_2016.tiff',
#   5.732020298503412e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/a3fad962-024f-49f6-8bb7-d9c0ee98ec65_rgb_2016.tiff',
#   6.113610200967309e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/1f761029-9f7f-433e-b7e8-dfe4d05d4c66_rgb_2016.tiff',
#   8.317163746063349e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/51b1f33a-c413-4171-b920-dcf78bfd6559_rgb_2016.tiff',
#   7.036817392878894e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00099d20-3095-4225-bd60-d5928247447a_rgb_2016.tiff',
#   6.074127471265871e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/037a1924-cb70-4c84-835a-33dbe169b364_rgb_2016.tiff',
#   3.1937394233887776e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/8d633940-0923-4fd0-8bfe-b50e9f686ec1_rgb_2016.tiff',
# ...

# %%
smallest_dist_images_2013 = [[filename] + list(distance_tuple) for filename, distance_tuple in zip(diff_images_2013, smallest_distances_2013)]
smallest_dist_images_2013
# Out:
# [['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/82c22f4b-a4ba-4e8b-90ae-31b238e420f9_rgb_2013.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/59eb6471-0d68-4b28-9a4a-ec2ecb767cc2_rgb_2016.tiff',
#   5.732020298503412e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/26e02272-87cd-411e-a271-131b0806132a_rgb_2013.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/a3fad962-024f-49f6-8bb7-d9c0ee98ec65_rgb_2016.tiff',
#   6.113610200967309e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/cf1d823e-a857-4ad9-9603-523d343774d5_rgb_2013.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/1f761029-9f7f-433e-b7e8-dfe4d05d4c66_rgb_2016.tiff',
#   8.317163746063349e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/56c6add0-d85c-4945-8d32-031653645098_rgb_2013.tiff',
# ...

# %%
_, ax = plt.subplots(10, 2, figsize=(16,16))

for i, image_tuple in enumerate(smallest_dist_images_2013):
    im_2013, im_2016, _ = image_tuple
   
    ax[i, 0].imshow(cv2.imread(im_2013))
    ax[i, 1].imshow(cv2.imread(im_2016))    
    if i >= 9:
        break

# %%
diff_bboxes_2014 = bboxes_for(diff_images_2014)
len(diff_bboxes_2014)
# Out:
# 280

# %%
diff_bboxes_2014[:10]
# Out:
# [(6.01898707106426, 50.93370735879644, 6.0192514696877915, 50.9335373712189),
#  (5.974445198544463, 50.93377337494111, 5.974709761698314, 50.93360348884157),
#  (5.942442429259489, 50.934099866293984, 5.942707112140961, 50.93393005315338),
#  (5.940042050856065, 50.93411135655713, 5.9403067426409155, 50.93394154889067),
#  (5.979781466838728, 50.93391472099465, 5.9800460111399, 50.933744822731605),
#  (5.934707871699086, 50.93413671230663, 5.934972583266897, 50.93396691680597),
#  (5.964577080810508, 50.93382302200634, 5.964841680598153, 50.9336531583998),
#  (5.975512020608215, 50.933767957313215, 5.975776579801002, 50.93359806878228),
#  (5.927773428724871, 50.934169307384344, 5.928038166005751, 50.93399952770094),
#  (5.942975846494648, 50.934097306144096, 5.943240527397504, 50.933927491787)]

# %%
smallest_distances_2014 = p.map(calc, diff_bboxes_2014)
smallest_distances_2014
# Out:
# [('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/59eb6471-0d68-4b28-9a4a-ec2ecb767cc2_rgb_2016.tiff',
#   5.732020298503412e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/a3fad962-024f-49f6-8bb7-d9c0ee98ec65_rgb_2016.tiff',
#   6.113610200967309e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/1f761029-9f7f-433e-b7e8-dfe4d05d4c66_rgb_2016.tiff',
#   8.317163746063349e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/51b1f33a-c413-4171-b920-dcf78bfd6559_rgb_2016.tiff',
#   7.036817392878894e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00099d20-3095-4225-bd60-d5928247447a_rgb_2016.tiff',
#   6.074127471265871e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/037a1924-cb70-4c84-835a-33dbe169b364_rgb_2016.tiff',
#   3.1937394233887776e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/8d633940-0923-4fd0-8bfe-b50e9f686ec1_rgb_2016.tiff',
# ...

# %%
smallest_dist_images_2014 = [[filename] + list(distance_tuple) for filename, distance_tuple in zip(diff_images_2014, smallest_distances_2014)]
smallest_dist_images_2014
# Out:
# [['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2014/82c22f4b-a4ba-4e8b-90ae-31b238e420f9_rgb_2014.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/59eb6471-0d68-4b28-9a4a-ec2ecb767cc2_rgb_2016.tiff',
#   5.732020298503412e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2014/26e02272-87cd-411e-a271-131b0806132a_rgb_2014.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/a3fad962-024f-49f6-8bb7-d9c0ee98ec65_rgb_2016.tiff',
#   6.113610200967309e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2014/cf1d823e-a857-4ad9-9603-523d343774d5_rgb_2014.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/1f761029-9f7f-433e-b7e8-dfe4d05d4c66_rgb_2016.tiff',
#   8.317163746063349e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2014/56c6add0-d85c-4945-8d32-031653645098_rgb_2014.tiff',
# ...

# %%
_, ax = plt.subplots(10, 2, figsize=(16,16))

for i, image_tuple in enumerate(smallest_dist_images_2014):
    im_2014, im_2016, _ = image_tuple
   
    ax[i, 0].imshow(cv2.imread(im_2014))
    ax[i, 1].imshow(cv2.imread(im_2016))    
    if i >= 9:
        break

# %%
diff_bboxes_2015 = bboxes_for(diff_images_2015)
len(diff_bboxes_2015)
# Out:
# 280

# %%
smallest_distances_2015 = p.map(calc, diff_bboxes_2015)
smallest_distances_2015
# Out:
# [('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/59eb6471-0d68-4b28-9a4a-ec2ecb767cc2_rgb_2016.tiff',
#   5.732020298503412e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/a3fad962-024f-49f6-8bb7-d9c0ee98ec65_rgb_2016.tiff',
#   6.113610200967309e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/1f761029-9f7f-433e-b7e8-dfe4d05d4c66_rgb_2016.tiff',
#   8.317163746063349e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/51b1f33a-c413-4171-b920-dcf78bfd6559_rgb_2016.tiff',
#   7.036817392878894e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/00099d20-3095-4225-bd60-d5928247447a_rgb_2016.tiff',
#   6.074127471265871e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/037a1924-cb70-4c84-835a-33dbe169b364_rgb_2016.tiff',
#   3.1937394233887776e-14),
#  ('/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/8d633940-0923-4fd0-8bfe-b50e9f686ec1_rgb_2016.tiff',
# ...

# %%
smallest_dist_images_2015 = [[filename] + list(distance_tuple) for filename, distance_tuple in zip(diff_images_2015, smallest_distances_2015)]
smallest_dist_images_2015
# Out:
# [['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2015/82c22f4b-a4ba-4e8b-90ae-31b238e420f9_rgb_2015.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/59eb6471-0d68-4b28-9a4a-ec2ecb767cc2_rgb_2016.tiff',
#   5.732020298503412e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2015/26e02272-87cd-411e-a271-131b0806132a_rgb_2015.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/a3fad962-024f-49f6-8bb7-d9c0ee98ec65_rgb_2016.tiff',
#   6.113610200967309e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2015/cf1d823e-a857-4ad9-9603-523d343774d5_rgb_2015.tiff',
#   '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75/1f761029-9f7f-433e-b7e8-dfe4d05d4c66_rgb_2016.tiff',
#   8.317163746063349e-14],
#  ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2015/56c6add0-d85c-4945-8d32-031653645098_rgb_2015.tiff',
# ...

# %%
_, ax = plt.subplots(10, 2, figsize=(16,16))

for i, image_tuple in enumerate(smallest_dist_images_2015):
    im_2015, im_2016, _ = image_tuple
   
    ax[i, 0].imshow(cv2.imread(im_2015))
    ax[i, 1].imshow(cv2.imread(im_2016))    
    if i >= 9:
        break

# %%
import csv

with open(r"uuids.csv", "w") as csvFile:
    csvWriter = csv.writer(csvFile, delimiter=";")
    csvWriter.writerow(["year", "uuid"])
    for uuid in diff_2013_2016:
        csvWriter.writerow([2013, uuid])    
    for uuid in diff_2014_2016:
        csvWriter.writerow([2014, uuid])    
    for uuid in diff_2015_2016:
        csvWriter.writerow([2015, uuid])

# %%
diff_2013_2016
# Out:
# {'0000085b-6f4a-475a-b800-9ed7619e8a67',
#  '00bcb86c-c04b-4deb-a98b-b29c593f36c5',
#  '0391ea6d-b2d1-4c92-a215-80293259be2a',
#  '047d2c9c-ea9d-4201-af0f-d2b3763c3cfd',
#  '04930d38-900d-462f-8774-30a73f2727ed',
#  '05e2c0a7-7150-4b09-a7da-f063b69abc04',
#  '06acb191-3989-42f5-bea3-954843bc1870',
#  '09e8d47d-38ed-4d2c-bf0d-ae694c0d9e1e',
#  '0ac5288a-9d71-443c-9c0a-9647df36f648',
#  '0b4a5392-e0bd-460e-b5eb-2f63a79edf81',
#  '0ba466b3-afa1-44b6-b1ae-d8f08c312468',
#  '0dbe3653-1434-4468-9c42-5bbb7a8482b7',
#  '0fccedb5-5bb2-43df-aedc-7b5428ee96c9',
#  '12cf7e0b-62cd-4d82-b377-a097087e03ec',
#  '13cf66ac-3d82-4da7-bef8-9b2b26c2dc57',
#  '13d720b8-08cd-4a54-ab3d-2c864daca05d',
#  '14d34989-77ef-4824-b264-46fa4a9f1531',
#  '15243f33-40da-49bd-9ef0-08eb4db2eacb',
#  '15a47bf8-1105-466c-a77a-0e723aacf1d2',
#  '15d9561e-b1ba-47e6-8e38-4e0c8672e1d2',
#  '15f075b3-1598-4d18-a6b4-182f7af8983d',
#  '1700fe4d-52e8-4b25-ab87-5f9dd889f8c6',
#  '1709e4a3-80b6-47c4-999b-9c0c888369dd',
# ...

# %%
def get_files_to_remove(image_dir):
    return [filename for filename in os.listdir(image_dir) for uuid in diff_2013_2016 if filename.startswith(uuid)]

# %%
files_to_remove_2013 = get_files_to_remove(image_dir_2013)
len(files_to_remove_2013)
# Out:
# 1680

# %%
files_to_remove_2014 = get_files_to_remove(image_dir_2014)
len(files_to_remove_2014)
# Out:
# 1680

# %%
files_to_remove_2015 = get_files_to_remove(image_dir_2015)
len(files_to_remove_2015)
# Out:
# 840

# %%
files_to_remove_2013 = [os.path.join(image_dir_2013, filename) for filename in files_to_remove_2013]
files_to_remove_2014 = [os.path.join(image_dir_2014, filename) for filename in files_to_remove_2014]
files_to_remove_2015 = [os.path.join(image_dir_2015, filename) for filename in files_to_remove_2015]

# %%
files_to_remove = files_to_remove_2013 + files_to_remove_2014 + files_to_remove_2015
files_to_remove.sort()
files_to_remove[:18]
# Out:
# ['/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2013.tiff',
#  '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2013_mask.tiff',
#  '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/0000085b-6f4a-475a-b800-9ed7619e8a67_ir_2013_masked.tiff',
#  '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2013.tiff',
#  '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2013_mask.tiff',
#  '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/0000085b-6f4a-475a-b800-9ed7619e8a67_rgb_2013_masked.tiff',
#  '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/00bcb86c-c04b-4deb-a98b-b29c593f36c5_ir_2013.tiff',
#  '/home/tdjg/Documents/DeepSolaris/Images/Tiles/Heerlen75x75-2013/00bcb86c-c04b-4deb-a98b-b29c593f36c5_ir_2013_mask.tiff',
# ...

# %%
def remove_files(file_paths):
    for path in file_paths:
        os.remove(path)

# %%
remove_files(files_to_remove)

# %%
image_dir_2016_2017 = os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75")
image_dir_2016 = os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2016")
image_dir_2017 = os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2017")

# %%
image_files_2016 = [filename for filename in image_files_2016_2017 if "_2016" in filename and filename.endswith("tiff")]
image_files_2016[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2016.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2016_mask.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2016_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2016.tiff']

# %%
image_files_2017 = [filename for filename in image_files_2016_2017 if "_2017" in filename and filename.endswith("tiff")]
image_files_2017[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2017.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2017_mask.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2017_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2017.tiff']

# %%
len(image_files_2016), len(image_files_2017)
# Out:
# (525102, 525102)

# %%
len(image_files_2016) + len(image_files_2017)
# Out:
# 1050204

# %%
from shutil import copyfile

def copyfiles(image_files, new_image_dir):
    for filename in image_files:
        src = os.path.join(image_dir_2016_2017, filename)
        dst = os.path.join(new_image_dir, filename)
        copyfile(src, dst)

# %%
copyfiles(image_files_2016, image_dir_2016)

# %%
copyfiles(image_files_2017, image_dir_2017)

# %%
image_files_2016 = os.listdir(os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2016"))
image_files_2016.sort()
image_files_2016[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2016_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2016.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2016_mask.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2016_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2016.tiff']

# %%
image_files_2016_rgb_2 = [filename for filename in image_files_2016 if filename.endswith("rgb_2016.tiff")]
image_files_2016_rgb_2[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2016.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2016.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2016.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2016.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2016.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2016.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2016.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2016.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2016.tiff',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781_rgb_2016.tiff']

# %%
len(image_files_2016_rgb_2)
# Out:
# 87517

# %%
image_files_2017 = os.listdir(os.path.join(ProjectPaths.instance().image_dir, r"Tiles/Heerlen75x75-2017"))
image_files_2017.sort()
image_files_2017[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_ir_2017_masked.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017_mask.tiff',
#  '00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2017.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2017_mask.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_ir_2017_masked.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2017.tiff']

# %%
image_files_2017_rgb_2 = [filename for filename in image_files_2017 if filename.endswith("rgb_2017.tiff")]
image_files_2017_rgb_2[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213_rgb_2017.tiff',
#  '00023872-f873-4889-9b80-113677b9e86a_rgb_2017.tiff',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777_rgb_2017.tiff',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021_rgb_2017.tiff',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61_rgb_2017.tiff',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390_rgb_2017.tiff',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45_rgb_2017.tiff',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba_rgb_2017.tiff',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb_rgb_2017.tiff',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781_rgb_2017.tiff']

# %%
len(image_files_2016_rgb_2)
# Out:
# 87517

# %%
uuid_2016_2 = rchop_list(image_files_2016_rgb_2, "_rgb_2016.tiff")
uuid_2016_2[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781']

# %%
uuid_2017_2 = rchop_list(image_files_2017_rgb_2, "_rgb_2017.tiff")
uuid_2017_2[:10]
# Out:
# ['00001900-3f87-4a57-8e1a-8fbdf3127213',
#  '00023872-f873-4889-9b80-113677b9e86a',
#  '00024a4c-54fe-4d74-838b-20b8ee7f4777',
#  '00031d78-fd98-4371-ac7f-8f2ddf487021',
#  '00036fd4-14a1-49a4-ae79-feaa26847d61',
#  '0003f83d-6e5b-4413-ac6b-d941996d3390',
#  '000469da-f33d-4f43-816d-9fe2c50b2e45',
#  '0004a6c7-799b-438e-bb3d-db24d7a58eba',
#  '00051b1f-4030-4eee-a4c2-1fd84fb558fb',
#  '0005eb2b-aedc-4f3e-adb9-d64bae29a781']

# %%
diff_2016_2016 = set(uuid_2016_2) ^ set(uuid_2016)
diff_2016_2016
# Out:
# set()

# %%
diff_2017_2017 = set(uuid_2017_2) ^ set(uuid_2017)
diff_2017_2017
# Out:
# set()
